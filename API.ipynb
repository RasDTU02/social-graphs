# %%
import pandas as pd
import time
import csv
import requests
import os
import requests

# %% [markdown]
# Functions for getting data from thje TMDB API

# %%
import os
import csv
import time
import pandas as pd
import requests

def fetch_movie_data(tmdb_id, i, TMDB_API_KEY):
    '''
    Fetches movie review data from TMDB API given a tmdb_id
    '''
    # rate limit: 40 requests every 10 seconds
    if i % 39 == 0:
        time.sleep(0.25)

    url = (
        f"https://api.themoviedb.org/3/movie/{tmdb_id}/reviews"
        f"?api_key={TMDB_API_KEY}&language=en-US"
    )

    data = requests.get(url).json()
    return data


def write_to_csv(row, filename="ml-latest/reviews.csv"):
    '''
    Appends a row to a csv file
    '''
    with open(filename, 'a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(row)


def get_last_row_movie(filename="ml-latest/reviews.csv"):
    '''
    Returns the movieId of the last row in the csv file
    '''
    with open(filename, 'r', encoding='utf-8') as f:
        last_line = f.readlines()[-1]
        return int(last_line.split(',')[0])


def process_movie_data(data, TMDB_API_KEY, file_path="ml-latest/reviews.csv"):
    '''
    Processes movie data fetched from TMDB API.
    Only pulls movieId + reviews.
    '''

    # check if csv exists
    if os.path.exists(file_path):
        last_movie_id = get_last_row_movie(file_path)
        print(f"Resuming from movieId: {last_movie_id}")

    else:
        last_movie_id = 0
        # write header
        with open(file_path, 'w', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            writer.writerow(["movieId", "reviews"])
        print("Creating new reviews.csv file")

    for i, (movieId, imdbId, tmdbId) in enumerate(data.itertuples(index=False)):

        # skip already processed movies
        if movieId <= last_movie_id:
            continue

        # skip NaN tmdb id
        if pd.isna(tmdbId):
            continue

        tmdbId = int(tmdbId)

        # get review data
        review_data = fetch_movie_data(tmdbId, i, TMDB_API_KEY)

        # extract reviews
        reviews_raw = review_data.get("results", [])
        reviews_texts = []

        for r in reviews_raw[:5]:  # take first 20 reviews only
            content = r.get("content", "")
            content = content.replace("\n", " ").replace(",", "").replace("'", "")
            reviews_texts.append(content)

        reviews_joined = "|".join(reviews_texts)

        # write to csv
        row = [movieId, reviews_joined]
        write_to_csv(row, file_path)

        print(f"Saved movieId {movieId}")

# %% [markdown]
# # Get the extra data
#
# IMPORTANT: API key to TMDB is required. It is free for non commercial applications.
#
#
# We have included the data we pulled so you don't need to run this part as the data is already present

# %%
TMDB_API_KEY = "be0552b72397e07ffaa4d7d488b22b92"

movies_df = pd.read_csv("data/links_action.csv")
process_movie_data(movies_df, TMDB_API_KEY=TMDB_API_KEY, file_path="data/reviews_final_one_AA.csv")
# Out:
# Creating new reviews.csv file
# Saved movieId 6
# Saved movieId 9
# Saved movieId 10
# Saved movieId 15
# Saved movieId 20
# Saved movieId 23
# Saved movieId 42
# Saved movieId 44
# Saved movieId 51
# Saved movieId 66
# Saved movieId 70
# Saved movieId 71
# Saved movieId 76
# Saved movieId 78
# Saved movieId 86
# Saved movieId 89
# Saved movieId 95
# Saved movieId 98
# Saved movieId 110
# Saved movieId 112
# Saved movieId 139
# Saved movieId 145
# Saved movieId 151
# Saved movieId 153
# Saved movieId 160
# Saved movieId 163
# Saved movieId 165
# Saved movieId 168
# Saved movieId 170
# Saved movieId 172
# Saved movieId 173
# Saved movieId 181
# Saved movieId 185
# Saved movieId 198
# Saved movieId 204
# Saved movieId 208
# Saved movieId 227
# Saved movieId 236
# Saved movieId 251
# Saved movieId 260
# Saved movieId 284
# Saved movieId 286
# Saved movieId 288
# Saved movieId 292
# Saved movieId 293
# Saved movieId 303
# Saved movieId 315
# Saved movieId 316
# Saved movieId 327
# Saved movieId 330
# Saved movieId 338
# Saved movieId 349
# Saved movieId 353
# Saved movieId 360
# Saved movieId 367
# Saved movieId 370
# Saved movieId 376
# Saved movieId 377
# Saved movieId 379
# Saved movieId 380
# Saved movieId 384
# Saved movieId 387
# Saved movieId 390
# Saved movieId 393
# Saved movieId 401
# Saved movieId 405
# Saved movieId 420
# Saved movieId 423
# Saved movieId 434
# Saved movieId 438
# Saved movieId 442
# Saved movieId 459
# Saved movieId 462
# Saved movieId 464
# Saved movieId 465
# Saved movieId 466
# Saved movieId 474
# Saved movieId 479
# Saved movieId 480
# Saved movieId 485
# Saved movieId 493
# Saved movieId 494
# Saved movieId 502
# Saved movieId 504
# Saved movieId 511
# Saved movieId 517
# Saved movieId 519
# Saved movieId 522
# Saved movieId 533
# Saved movieId 541
# Saved movieId 544
# Saved movieId 546
# Saved movieId 547
# Saved movieId 548
# Saved movieId 552
# Saved movieId 553
# Saved movieId 558
# Saved movieId 589
# Saved movieId 591
# Saved movieId 592
# Saved movieId 600
# Saved movieId 610
# Saved movieId 611
# Saved movieId 647
# Saved movieId 648
# Saved movieId 653
# Saved movieId 667
# Saved movieId 675
# Saved movieId 688
# Saved movieId 692
# Saved movieId 694
# Saved movieId 704
# Saved movieId 733
# Saved movieId 736
# Saved movieId 737
# Saved movieId 748
# Saved movieId 761
# Saved movieId 780
# Saved movieId 786
# Saved movieId 798
# Saved movieId 809
# Saved movieId 815
# Saved movieId 836
# Saved movieId 839
# Saved movieId 849
# Saved movieId 861
# Saved movieId 875
# Saved movieId 876
# Saved movieId 886
# Saved movieId 908
# Saved movieId 940
# Saved movieId 980
# Saved movieId 990
# Saved movieId 996
# Saved movieId 998
# Saved movieId 1004
# Saved movieId 1036
# Saved movieId 1037
# Saved movieId 1047
# Saved movieId 1049
# Saved movieId 1100
# Saved movieId 1101
# Saved movieId 1102
# Saved movieId 1110
# Saved movieId 1112
# Saved movieId 1118
# Saved movieId 1127
# Saved movieId 1129
# Saved movieId 1134
# Saved movieId 1168
# Saved movieId 1170
# Saved movieId 1196
# Saved movieId 1197
# Saved movieId 1198
# Saved movieId 1200
# Saved movieId 1201
# Saved movieId 1208
# Saved movieId 1209
# Saved movieId 1210
# Saved movieId 1215
# Saved movieId 1218
# Saved movieId 1220
# Saved movieId 1224
# Saved movieId 1233
# Saved movieId 1240
# Saved movieId 1249
# Saved movieId 1254
# Saved movieId 1261
# Saved movieId 1262
# Saved movieId 1264
# Saved movieId 1274
# Saved movieId 1275
# Saved movieId 1287
# Saved movieId 1291
# Saved movieId 1304
# Saved movieId 1320
# Saved movieId 1356
# Saved movieId 1370
# Saved movieId 1372
# Saved movieId 1373
# Saved movieId 1374
# Saved movieId 1375
# Saved movieId 1377
# Saved movieId 1378
# Saved movieId 1379
# Saved movieId 1382
# Saved movieId 1383
# Saved movieId 1385
# Saved movieId 1387
# Saved movieId 1389
# Saved movieId 1391
# Saved movieId 1396
# Saved movieId 1408
# Saved movieId 1424
# Saved movieId 1427
# Saved movieId 1429
# Saved movieId 1431
# Saved movieId 1432
# Saved movieId 1438
# Saved movieId 1465
# Saved movieId 1473
# Saved movieId 1479
# Saved movieId 1488
# Saved movieId 1495
# Saved movieId 1497
# Saved movieId 1499
# Saved movieId 1515
# Saved movieId 1517
# Saved movieId 1518
# Saved movieId 1523
# Saved movieId 1525
# Saved movieId 1527
# Saved movieId 1544
# Saved movieId 1552
# Saved movieId 1556
# Saved movieId 1562
# Saved movieId 1573
# Saved movieId 1580
# Saved movieId 1586
# Saved movieId 1587
# Saved movieId 1589
# Saved movieId 1591
# Saved movieId 1599
# Saved movieId 1604
# Saved movieId 1606
# Saved movieId 1608
# Saved movieId 1610
# Saved movieId 1616
# Saved movieId 1626
# Saved movieId 1631
# Saved movieId 1636
# Saved movieId 1667
# Saved movieId 1676
# Saved movieId 1681
# Saved movieId 1687
# Saved movieId 1690
# Saved movieId 1720
# Saved movieId 1722
# Saved movieId 1726
# Saved movieId 1739
# Saved movieId 1740
# Saved movieId 1744
# Saved movieId 1752
# Saved movieId 1762
# Saved movieId 1769
# Saved movieId 1772
# Saved movieId 1773
# Saved movieId 1788
# Saved movieId 1792
# Saved movieId 1796
# Saved movieId 1801
# Saved movieId 1831
# Saved movieId 1832
# Saved movieId 1833
# Saved movieId 1858
# Saved movieId 1866
# Saved movieId 1867
# Saved movieId 1869
# Saved movieId 1882
# Saved movieId 1909
# Saved movieId 1917
# Saved movieId 1918
# Saved movieId 1925
# Saved movieId 1927
# Saved movieId 1953
# Saved movieId 2000
# Saved movieId 2001
# Saved movieId 2002
# Saved movieId 2005
# Saved movieId 2006
# Saved movieId 2013
# Saved movieId 2019
# Saved movieId 2028
# Saved movieId 2041
# Saved movieId 2048
# Saved movieId 2055
# Saved movieId 2058
# Saved movieId 2094
# Saved movieId 2105
# Saved movieId 2115
# Saved movieId 2126
# Saved movieId 2153
# Saved movieId 2164
# Saved movieId 2167
# Saved movieId 2170
# Saved movieId 2193
# Saved movieId 2194
# Saved movieId 2196
# Saved movieId 2246
# Saved movieId 2273
# Saved movieId 2275
# Saved movieId 2278
# Saved movieId 2281
# Saved movieId 2288
# Saved movieId 2307
# Saved movieId 2308
# Saved movieId 2322
# Saved movieId 2334
# Saved movieId 2344
# Saved movieId 2353
# Saved movieId 2364
# Saved movieId 2365
# Saved movieId 2366
# Saved movieId 2370
# Saved movieId 2373
# Saved movieId 2376
# Saved movieId 2393
# Saved movieId 2402
# Saved movieId 2403
# Saved movieId 2404
# Saved movieId 2405
# Saved movieId 2406
# Saved movieId 2409
# Saved movieId 2410
# Saved movieId 2411
# Saved movieId 2412
# Saved movieId 2414
# Saved movieId 2421
# Saved movieId 2422
# Saved movieId 2427
# Saved movieId 2429
# Saved movieId 2457
# Saved movieId 2468
# Saved movieId 2471
# Saved movieId 2475
# Saved movieId 2476
# Saved movieId 2487
# Saved movieId 2490
# Saved movieId 2521
# Saved movieId 2524
# Saved movieId 2525
# Saved movieId 2527
# Saved movieId 2528
# Saved movieId 2529
# Saved movieId 2530
# Saved movieId 2531
# Saved movieId 2532
# Saved movieId 2533
# Saved movieId 2534
# Saved movieId 2535
# Saved movieId 2540
# Saved movieId 2549
# Saved movieId 2568
# Saved movieId 2571
# Saved movieId 2582
# Saved movieId 2600
# Saved movieId 2602
# Saved movieId 2614
# Saved movieId 2616
# Saved movieId 2617
# Saved movieId 2625
# Saved movieId 2628
# Saved movieId 2640
# Saved movieId 2641
# Saved movieId 2642
# Saved movieId 2643
# Saved movieId 2662
# Saved movieId 2683
# Saved movieId 2692
# Saved movieId 2701
# Saved movieId 2716
# Saved movieId 2720
# Saved movieId 2722
# Saved movieId 2723
# Saved movieId 2728
# Saved movieId 2735
# Saved movieId 2737
# Saved movieId 2741
# Saved movieId 2748
# Saved movieId 2756
# Saved movieId 2763
# Saved movieId 2802
# Saved movieId 2807
# Saved movieId 2808
# Saved movieId 2812
# Saved movieId 2815
# Saved movieId 2816
# Saved movieId 2817
# Saved movieId 2818
# Saved movieId 2823
# Saved movieId 2826
# Saved movieId 2835
# Saved movieId 2879
# Saved movieId 2880
# Saved movieId 2881
# Saved movieId 2887
# Saved movieId 2890
# Saved movieId 2892
# Saved movieId 2893
# Saved movieId 2905
# Saved movieId 2916
# Saved movieId 2924
# Saved movieId 2944
# Saved movieId 2947
# Saved movieId 2948
# Saved movieId 2949
# Saved movieId 2951
# Saved movieId 2956
# Saved movieId 2959
# Saved movieId 2965
# Saved movieId 2985
# Saved movieId 2986
# Saved movieId 2989
# Saved movieId 2990
# Saved movieId 2991
# Saved movieId 2993
# Saved movieId 3000
# Saved movieId 3020
# Saved movieId 3029
# Saved movieId 3030
# Saved movieId 3032
# Saved movieId 3062
# Saved movieId 3066
# Saved movieId 3082
# Saved movieId 3104
# Saved movieId 3107
# Saved movieId 3113
# Saved movieId 3137
# Saved movieId 3139
# Saved movieId 3153
# Saved movieId 3165
# Saved movieId 3184
# Saved movieId 3197
# Saved movieId 3204
# Saved movieId 3208
# Saved movieId 3256
# Saved movieId 3264
# Saved movieId 3265
# Saved movieId 3267
# Saved movieId 3268
# Saved movieId 3275
# Saved movieId 3279
# Saved movieId 3283
# Saved movieId 3314
# Saved movieId 3316
# Saved movieId 3372
# Saved movieId 3384
# Saved movieId 3389
# Saved movieId 3404
# Saved movieId 3405
# Saved movieId 3406
# Saved movieId 3430
# Saved movieId 3431
# Saved movieId 3432
# Saved movieId 3433
# Saved movieId 3434
# Saved movieId 3438
# Saved movieId 3439
# Saved movieId 3440
# Saved movieId 3441
# Saved movieId 3442
# Saved movieId 3443
# Saved movieId 3444
# Saved movieId 3452
# Saved movieId 3508
# Saved movieId 3519
# Saved movieId 3523
# Saved movieId 3527
# Saved movieId 3541
# Saved movieId 3555
# Saved movieId 3563
# Saved movieId 3576
# Saved movieId 3578
# Saved movieId 3584
# Saved movieId 3593
# Saved movieId 3623
# Saved movieId 3624
# Saved movieId 3628
# Saved movieId 3633
# Saved movieId 3635
# Saved movieId 3638
# Saved movieId 3639
# Saved movieId 3643
# Saved movieId 3654
# Saved movieId 3667
# Saved movieId 3681
# Saved movieId 3682
# Saved movieId 3697
# Saved movieId 3698
# Saved movieId 3702
# Saved movieId 3703
# Saved movieId 3704
# Saved movieId 3705
# Saved movieId 3710
# Saved movieId 3716
# Saved movieId 3717
# Saved movieId 3726
# Saved movieId 3729
# Saved movieId 3740
# Saved movieId 3744
# Saved movieId 3745
# Saved movieId 3753
# Saved movieId 3761
# Saved movieId 3763
# Saved movieId 3764
# Saved movieId 3766
# Saved movieId 3767
# Saved movieId 3768
# Saved movieId 3769
# Saved movieId 3771
# Saved movieId 3781
# Saved movieId 3782
# Saved movieId 3793
# Saved movieId 3802
# Saved movieId 3805
# Saved movieId 3827
# Saved movieId 3836
# Saved movieId 3837
# Saved movieId 3841
# Saved movieId 3864
# Saved movieId 3868
# Saved movieId 3877
# Saved movieId 3879
# Saved movieId 3889
# Saved movieId 3898
# Saved movieId 3907
# Saved movieId 3946
# Saved movieId 3947
# Saved movieId 3957
# Saved movieId 3959
# Saved movieId 3972
# Saved movieId 3977
# Saved movieId 3981
# Saved movieId 3984
# Saved movieId 3986
# Saved movieId 3996
# Saved movieId 3997
# Saved movieId 3999
# Saved movieId 4001
# Saved movieId 4005
# Saved movieId 4026
# Saved movieId 4042
# Saved movieId 4044
# Saved movieId 4053
# Saved movieId 4064
# Saved movieId 4065
# Saved movieId 4066
# Saved movieId 4084
# Saved movieId 4085
# Saved movieId 4086
# Saved movieId 4099
# Saved movieId 4103
# Saved movieId 4106
# Saved movieId 4121
# Saved movieId 4133
# Saved movieId 4142
# Saved movieId 4159
# Saved movieId 4161
# Saved movieId 4163
# Saved movieId 4166
# Saved movieId 4180
# Saved movieId 4199
# Saved movieId 4200
# Saved movieId 4203
# Saved movieId 4207
# Saved movieId 4210
# Saved movieId 4224
# Saved movieId 4232
# Saved movieId 4238
# Saved movieId 4262
# Saved movieId 4265
# Saved movieId 4270
# Saved movieId 4275
# Saved movieId 4295
# Saved movieId 4299
# Saved movieId 4310
# Saved movieId 4339
# Saved movieId 4344
# Saved movieId 4351
# Saved movieId 4353
# Saved movieId 4355
# Saved movieId 4363
# Saved movieId 4367
# Saved movieId 4369
# Saved movieId 4387
# Saved movieId 4396
# Saved movieId 4397
# Saved movieId 4398
# Saved movieId 4401
# Saved movieId 4434
# Saved movieId 4438
# Saved movieId 4440
# Saved movieId 4441
# Saved movieId 4442
# Saved movieId 4443
# Saved movieId 4444
# Saved movieId 4448
# Saved movieId 4466
# Saved movieId 4488
# Saved movieId 4497
# Saved movieId 4498
# Saved movieId 4528
# Saved movieId 4531
# Saved movieId 4542
# Saved movieId 4543
# Saved movieId 4548
# Saved movieId 4552
# Saved movieId 4553
# Saved movieId 4565
# Saved movieId 4566
# Saved movieId 4567
# Saved movieId 4568
# Saved movieId 4569
# Saved movieId 4572
# Saved movieId 4574
# Saved movieId 4580
# Saved movieId 4583
# Saved movieId 4594
# Saved movieId 4597
# Saved movieId 4613
# Saved movieId 4614
# Saved movieId 4620
# Saved movieId 4629
# Saved movieId 4630
# Saved movieId 4632
# Saved movieId 4635
# Saved movieId 4636
# Saved movieId 4637
# Saved movieId 4638
# Saved movieId 4640
# Saved movieId 4643
# Saved movieId 4651
# Saved movieId 4654
# Saved movieId 4673
# Saved movieId 4675
# Saved movieId 4682
# Saved movieId 4691
# Saved movieId 4701
# Saved movieId 4717
# Saved movieId 4719
# Saved movieId 4721
# Saved movieId 4748
# Saved movieId 4749
# Saved movieId 4750
# Saved movieId 4751
# Saved movieId 4756
# Saved movieId 4781
# Saved movieId 4799
# Saved movieId 4800
# Saved movieId 4802
# Saved movieId 4818
# Saved movieId 4826
# Saved movieId 4846
# Saved movieId 4850
# Saved movieId 4853
# Saved movieId 4855
# Saved movieId 4866
# Saved movieId 4868
# Saved movieId 4869
# Saved movieId 4879
# Saved movieId 4887
# Saved movieId 4894
# Saved movieId 4901
# Saved movieId 4907
# Saved movieId 4915
# Saved movieId 4923
# Saved movieId 4930
# Saved movieId 4934
# Saved movieId 4939
# Saved movieId 4941
# Saved movieId 4946
# Saved movieId 4947
# Saved movieId 4949
# Saved movieId 4950
# Saved movieId 4956
# Saved movieId 4958
# Saved movieId 4965
# Saved movieId 4985
# Saved movieId 4986
# Saved movieId 4987
# Saved movieId 5001
# Saved movieId 5006
# Saved movieId 5010
# Saved movieId 5020
# Saved movieId 5026
# Saved movieId 5027
# Saved movieId 5039
# Saved movieId 5040
# Saved movieId 5046
# Saved movieId 5047
# Saved movieId 5049
# Saved movieId 5055
# Saved movieId 5064
# Saved movieId 5069
# Saved movieId 5084
# Saved movieId 5091
# Saved movieId 5093
# Saved movieId 5094
# Saved movieId 5138
# Saved movieId 5152
# Saved movieId 5154
# Saved movieId 5155
# Saved movieId 5156
# Saved movieId 5160
# Saved movieId 5170
# Saved movieId 5171
# Saved movieId 5181
# Saved movieId 5182
# Saved movieId 5212
# Saved movieId 5217
# Saved movieId 5219
# Saved movieId 5220
# Saved movieId 5235
# Saved movieId 5240
# Saved movieId 5243
# Saved movieId 5244
# Saved movieId 5246
# Saved movieId 5247
# Saved movieId 5248
# Saved movieId 5252
# Saved movieId 5254
# Saved movieId 5264
# Saved movieId 5277
# Saved movieId 5300
# Saved movieId 5301
# Saved movieId 5302
# Saved movieId 5313
# Saved movieId 5336
# Saved movieId 5349
# Saved movieId 5369
# Saved movieId 5370
# Saved movieId 5376
# Saved movieId 5378
# Saved movieId 5388
# Saved movieId 5409
# Saved movieId 5414
# Saved movieId 5418
# Saved movieId 5420
# Saved movieId 5423
# Saved movieId 5432
# Saved movieId 5438
# Saved movieId 5442
# Saved movieId 5445
# Saved movieId 5459
# Saved movieId 5460
# Saved movieId 5463
# Saved movieId 5469
# Saved movieId 5478
# Saved movieId 5479
# Saved movieId 5490
# Saved movieId 5493
# Saved movieId 5507
# Saved movieId 5521
# Saved movieId 5522
# Saved movieId 5523
# Saved movieId 5540
# Saved movieId 5541
# Saved movieId 5542
# Saved movieId 5543
# Saved movieId 5558
# Saved movieId 5574
# Saved movieId 5580
# Saved movieId 5609
# Saved movieId 5612
# Saved movieId 5621
# Saved movieId 5628
# Saved movieId 5638
# Saved movieId 5657
# Saved movieId 5665
# Saved movieId 5678
# Saved movieId 5691
# Saved movieId 5692
# Saved movieId 5700
# Saved movieId 5702
# Saved movieId 5728
# Saved movieId 5730
# Saved movieId 5743
# Saved movieId 5746
# Saved movieId 5751
# Saved movieId 5758
# Saved movieId 5782
# Saved movieId 5785
# Saved movieId 5786
# Saved movieId 5796
# Saved movieId 5803
# Saved movieId 5815
# Saved movieId 5822
# Saved movieId 5824
# Saved movieId 5831
# Saved movieId 5833
# Saved movieId 5843
# Saved movieId 5872
# Saved movieId 5880
# Saved movieId 5892
# Saved movieId 5898
# Saved movieId 5899
# Saved movieId 5903
# Saved movieId 5915
# Saved movieId 5922
# Saved movieId 5934
# Saved movieId 5935
# Saved movieId 5944
# Saved movieId 5961
# Saved movieId 5964
# Saved movieId 5965
# Saved movieId 5985
# Saved movieId 5999
# Saved movieId 6010
# Saved movieId 6013
# Saved movieId 6014
# Saved movieId 6016
# Saved movieId 6045
# Saved movieId 6051
# Saved movieId 6057
# Saved movieId 6059
# Saved movieId 6078
# Saved movieId 6080
# Saved movieId 6095
# Saved movieId 6099
# Saved movieId 6130
# Saved movieId 6137
# Saved movieId 6138
# Saved movieId 6149
# Saved movieId 6156
# Saved movieId 6157
# Saved movieId 6168
# Saved movieId 6176
# Saved movieId 6177
# Saved movieId 6179
# Saved movieId 6185
# Saved movieId 6186
# Saved movieId 6196
# Saved movieId 6209
# Saved movieId 6210
# Saved movieId 6213
# Saved movieId 6219
# Saved movieId 6240
# Saved movieId 6261
# Saved movieId 6264
# Saved movieId 6276
# Saved movieId 6280
# Saved movieId 6283
# Saved movieId 6294
# Saved movieId 6300
# Saved movieId 6317
# Saved movieId 6333
# Saved movieId 6350
# Saved movieId 6365
# Saved movieId 6378
# Saved movieId 6383
# Saved movieId 6387
# Saved movieId 6395
# Saved movieId 6398
# Saved movieId 6417
# Saved movieId 6421
# Saved movieId 6446
# Saved movieId 6448
# Saved movieId 6457
# Saved movieId 6484
# Saved movieId 6502
# Saved movieId 6503
# Saved movieId 6506
# Saved movieId 6518
# Saved movieId 6534
# Saved movieId 6537
# Saved movieId 6539
# Saved movieId 6541
# Saved movieId 6548
# Saved movieId 6550
# Saved movieId 6560
# Saved movieId 6564
# Saved movieId 6566
# Saved movieId 6574
# Saved movieId 6575
# Saved movieId 6576
# Saved movieId 6577
# Saved movieId 6582
# Saved movieId 6583
# Saved movieId 6585
# Saved movieId 6595
# Saved movieId 6597
# Saved movieId 6615
# Saved movieId 6616
# Saved movieId 6618
# Saved movieId 6624
# Saved movieId 6637
# Saved movieId 6642
# Saved movieId 6645
# Saved movieId 6664
# Saved movieId 6686
# Saved movieId 6709
# Saved movieId 6714
# Saved movieId 6720
# Saved movieId 6721
# Saved movieId 6722
# Saved movieId 6723
# Saved movieId 6730
# Saved movieId 6754
# Saved movieId 6764
# Saved movieId 6795
# Saved movieId 6800
# Saved movieId 6805
# Saved movieId 6806
# Saved movieId 6808
# Saved movieId 6812
# Saved movieId 6814
# Saved movieId 6815
# Saved movieId 6835
# Saved movieId 6857
# Saved movieId 6872
# Saved movieId 6874
# Saved movieId 6882
# Saved movieId 6893
# Saved movieId 6900
# Saved movieId 6934
# Saved movieId 6946
# Saved movieId 6959
# Saved movieId 6966
# Saved movieId 6968
# Saved movieId 6977
# Saved movieId 6990
# Saved movieId 6994
# Saved movieId 6995
# Saved movieId 6996
# Saved movieId 7000
# Saved movieId 7004
# Saved movieId 7007
# Saved movieId 7014
# Saved movieId 7016
# Saved movieId 7017
# Saved movieId 7022
# Saved movieId 7027
# Saved movieId 7031
# Saved movieId 7035
# Saved movieId 7040
# Saved movieId 7047
# Saved movieId 7048
# Saved movieId 7056
# Saved movieId 7070
# Saved movieId 7072
# Saved movieId 7076
# Saved movieId 7090
# Saved movieId 7108
# Saved movieId 7113
# Saved movieId 7127
# Saved movieId 7133
# Saved movieId 7138
# Saved movieId 7143
# Saved movieId 7153
# Saved movieId 7163
# Saved movieId 7164
# Saved movieId 7175
# Saved movieId 7192
# Saved movieId 7193
# Saved movieId 7230
# Saved movieId 7235
# Saved movieId 7240
# Saved movieId 7242
# Saved movieId 7248
# Saved movieId 7262
# Saved movieId 7272
# Saved movieId 7284
# Saved movieId 7298
# Saved movieId 7300
# Saved movieId 7302
# Saved movieId 7307
# Saved movieId 7309
# Saved movieId 7310
# Saved movieId 7313
# Saved movieId 7325
# Saved movieId 7345
# Saved movieId 7360
# Saved movieId 7369
# Saved movieId 7373
# Saved movieId 7376
# Saved movieId 7381
# Saved movieId 7387
# Saved movieId 7394
# Saved movieId 7399
# Saved movieId 7409
# Saved movieId 7410
# Saved movieId 7438
# Saved movieId 7439
# Saved movieId 7445
# Saved movieId 7453
# Saved movieId 7454
# Saved movieId 7458
# Saved movieId 7475
# Saved movieId 7482
# Saved movieId 7483
# Saved movieId 7562
# Saved movieId 7569
# Saved movieId 7570
# Saved movieId 7573
# Saved movieId 7657
# Saved movieId 7700
# Saved movieId 7704
# Saved movieId 7720
# Saved movieId 7723
# Saved movieId 7724
# Saved movieId 7725
# Saved movieId 7754
# Saved movieId 7756
# Saved movieId 7757
# Saved movieId 7766
# Saved movieId 7769
# Saved movieId 7782
# Saved movieId 7787
# Saved movieId 7802
# Saved movieId 7814
# Saved movieId 7827
# Saved movieId 7838
# Saved movieId 7844
# Saved movieId 7892
# Saved movieId 7893
# Saved movieId 7894
# Saved movieId 7899
# Saved movieId 7915
# Saved movieId 7923
# Saved movieId 7925
# Saved movieId 7980
# Saved movieId 7991
# Saved movieId 7995
# Saved movieId 8016
# Saved movieId 8037
# Saved movieId 8045
# Saved movieId 8093
# Saved movieId 8117
# Saved movieId 8118
# Saved movieId 8122
# Saved movieId 8132
# Saved movieId 8142
# Saved movieId 8167
# Saved movieId 8235
# Saved movieId 8241
# Saved movieId 8253
# Saved movieId 8257
# Saved movieId 8258
# Saved movieId 8259
# Saved movieId 8268
# Saved movieId 8290
# Saved movieId 8361
# Saved movieId 8369
# Saved movieId 8370
# Saved movieId 8371
# Saved movieId 8403
# Saved movieId 8446
# Saved movieId 8481
# Saved movieId 8483
# Saved movieId 8493
# Saved movieId 8500
# Saved movieId 8501
# Saved movieId 8520
# Saved movieId 8531
# Saved movieId 8537
# Saved movieId 8543
# Saved movieId 8576
# Saved movieId 8578
# Saved movieId 8585
# Saved movieId 8593
# Saved movieId 8595
# Saved movieId 8597
# Saved movieId 8604
# Saved movieId 8605
# Saved movieId 8631
# Saved movieId 8633
# Saved movieId 8634
# Saved movieId 8636
# Saved movieId 8640
# Saved movieId 8644
# Saved movieId 8646
# Saved movieId 8652
# Saved movieId 8662
# Saved movieId 8665
# Saved movieId 8666
# Saved movieId 8675
# Saved movieId 8676
# Saved movieId 8677
# Saved movieId 8678
# Saved movieId 8719
# Saved movieId 8730
# Saved movieId 8733
# Saved movieId 8750
# Saved movieId 8756
# Saved movieId 8780
# Saved movieId 8782
# Saved movieId 8787
# Saved movieId 8788
# Saved movieId 8795
# Saved movieId 8798
# Saved movieId 8810
# Saved movieId 8811
# Saved movieId 8816
# Saved movieId 8832
# Saved movieId 8846
# Saved movieId 8860
# Saved movieId 8861
# Saved movieId 8865
# Saved movieId 8894
# Saved movieId 8901
# Saved movieId 8908
# Saved movieId 8912
# Saved movieId 8917
# Saved movieId 8926
# Saved movieId 8927
# Saved movieId 8937
# Saved movieId 8961
# Saved movieId 8968
# Saved movieId 8972
# Saved movieId 8977
# Saved movieId 8983
# Saved movieId 8984
# Saved movieId 8985
# Saved movieId 25840
# Saved movieId 25866
# Saved movieId 25878
# Saved movieId 25879
# Saved movieId 25888
# Saved movieId 25946
# Saved movieId 25961
# Saved movieId 25962
# Saved movieId 25976
# Saved movieId 25979
# Saved movieId 25995
# Saved movieId 26005
# Saved movieId 26012
# Saved movieId 26035
# Saved movieId 26043
# Saved movieId 26109
# Saved movieId 26117
# Saved movieId 26137
# Saved movieId 26144
# Saved movieId 26148
# Saved movieId 26152
# Saved movieId 26155
# Saved movieId 26156
# Saved movieId 26159
# Saved movieId 26160
# Saved movieId 26169
# Saved movieId 26172
# Saved movieId 26181
# Saved movieId 26183
# Saved movieId 26184
# Saved movieId 26204
# Saved movieId 26216
# Saved movieId 26220
# Saved movieId 26223
# Saved movieId 26236
# Saved movieId 26242
# Saved movieId 26254
# Saved movieId 26269
# Saved movieId 26270
# Saved movieId 26289
# Saved movieId 26304
# Saved movieId 26307
# Saved movieId 26309
# Saved movieId 26322
# Saved movieId 26339
# Saved movieId 26340
# Saved movieId 26344
# Saved movieId 26353
# Saved movieId 26354
# Saved movieId 26375
# Saved movieId 26393
# Saved movieId 26397
# Saved movieId 26399
# Saved movieId 26401
# Saved movieId 26413
# Saved movieId 26425
# Saved movieId 26438
# Saved movieId 26450
# Saved movieId 26459
# Saved movieId 26464
# Saved movieId 26465
# Saved movieId 26488
# Saved movieId 26490
# Saved movieId 26495
# Saved movieId 26504
# Saved movieId 26513
# Saved movieId 26526
# Saved movieId 26530
# Saved movieId 26547
# Saved movieId 26551
# Saved movieId 26559
# Saved movieId 26569
# Saved movieId 26580
# Saved movieId 26582
# Saved movieId 26589
# Saved movieId 26593
# Saved movieId 26600
# Saved movieId 26602
# Saved movieId 26606
# Saved movieId 26615
# Saved movieId 26641
# Saved movieId 26675
# Saved movieId 26681
# Saved movieId 26682
# Saved movieId 26688
# Saved movieId 26696
# Saved movieId 26736
# Saved movieId 26746
# Saved movieId 26755
# Saved movieId 26764
# Saved movieId 26765
# Saved movieId 26792
# Saved movieId 26801
# Saved movieId 26818
# Saved movieId 26819
# Saved movieId 26828
# Saved movieId 26834
# Saved movieId 26840
# Saved movieId 26842
# Saved movieId 26851
# Saved movieId 26865
# Saved movieId 26886
# Saved movieId 26898
# Saved movieId 26911
# Saved movieId 26945
# Saved movieId 26969
# Saved movieId 26975
# Saved movieId 26981
# Saved movieId 26985
# Saved movieId 26989
# Saved movieId 26991
# Saved movieId 27003
# Saved movieId 27018
# Saved movieId 27022
# Saved movieId 27032
# Saved movieId 27050
# Saved movieId 27109
# Saved movieId 27112
# Saved movieId 27132
# Saved movieId 27134
# Saved movieId 27156
# Saved movieId 27189
# Saved movieId 27193
# Saved movieId 27276
# Saved movieId 27316
# Saved movieId 27328
# Saved movieId 27343
# Saved movieId 27344
# Saved movieId 27357
# Saved movieId 27376
# Saved movieId 27426
# Saved movieId 27441
# Saved movieId 27455
# Saved movieId 27458
# Saved movieId 27477
# Saved movieId 27480
# Saved movieId 27485
# Saved movieId 27488
# Saved movieId 27497
# Saved movieId 27530
# Saved movieId 27548
# Saved movieId 27595
# Saved movieId 27598
# Saved movieId 27603
# Saved movieId 27606
# Saved movieId 27608
# Saved movieId 27618
# Saved movieId 27643
# Saved movieId 27656
# Saved movieId 27657
# Saved movieId 27660
# Saved movieId 27675
# Saved movieId 27689
# Saved movieId 27692
# Saved movieId 27695
# Saved movieId 27704
# Saved movieId 27711
# Saved movieId 27728
# Saved movieId 27735
# Saved movieId 27742
# Saved movieId 27754
# Saved movieId 27759
# Saved movieId 27779
# Saved movieId 27787
# Saved movieId 27793
# Saved movieId 27801
# Saved movieId 27802
# Saved movieId 27816
# Saved movieId 27824
# Saved movieId 27827
# Saved movieId 27828
# Saved movieId 27837
# Saved movieId 27856
# Saved movieId 27865
# Saved movieId 27869
# Saved movieId 27881
# Saved movieId 27905
# Saved movieId 30764
# Saved movieId 30861
# Saved movieId 30896
# Saved movieId 30905
# Saved movieId 31101
# Saved movieId 31184
# Saved movieId 31205
# Saved movieId 31221
# Saved movieId 31255
# Saved movieId 31290
# Saved movieId 31367
# Saved movieId 31420
# Saved movieId 31424
# Saved movieId 31467
# Saved movieId 31528
# Saved movieId 31553
# Saved movieId 31617
# Saved movieId 31645
# Saved movieId 31647
# Saved movieId 31660
# Saved movieId 31664
# Saved movieId 31672
# Saved movieId 31696
# Saved movieId 31705
# Saved movieId 31804
# Saved movieId 31867
# Saved movieId 31878
# Saved movieId 31881
# Saved movieId 31892
# Saved movieId 31923
# Saved movieId 32017
# Saved movieId 32029
# Saved movieId 32076
# Saved movieId 32078
# Saved movieId 32088
# Saved movieId 32174
# Saved movieId 32196
# Saved movieId 32211
# Saved movieId 32243
# Saved movieId 32263
# Saved movieId 32300
# Saved movieId 32387
# Saved movieId 32433
# Saved movieId 32440
# Saved movieId 32460
# Saved movieId 32501
# Saved movieId 32511
# Saved movieId 32518
# Saved movieId 32551
# Saved movieId 32560
# Saved movieId 32587
# Saved movieId 32593
# Saved movieId 32596
# Saved movieId 32617
# Saved movieId 32632
# Saved movieId 32691
# Saved movieId 32721
# Saved movieId 32830
# Saved movieId 32898
# Saved movieId 33027
# Saved movieId 33036
# Saved movieId 33098
# Saved movieId 33129
# Saved movieId 33132
# Saved movieId 33158
# Saved movieId 33162
# Saved movieId 33376
# Saved movieId 33437
# Saved movieId 33493
# Saved movieId 33573
# Saved movieId 33579
# Saved movieId 33655
# Saved movieId 33672
# Saved movieId 33679
# Saved movieId 33681
# Saved movieId 33755
# Saved movieId 33794
# Saved movieId 33799
# Saved movieId 33801
# Saved movieId 33834
# Saved movieId 33861
# Saved movieId 33905
# Saved movieId 33919
# Saved movieId 33921
# Saved movieId 33994
# Saved movieId 34004
# Saved movieId 34048
# Saved movieId 34115
# Saved movieId 34150
# Saved movieId 34231
# Saved movieId 34292
# Saved movieId 34319
# Saved movieId 34323
# Saved movieId 34332
# Saved movieId 34334
# Saved movieId 34405
# Saved movieId 34435
# Saved movieId 34450
# Saved movieId 34511
# Saved movieId 34520
# Saved movieId 34526
# Saved movieId 34534
# Saved movieId 34536
# Saved movieId 34583
# Saved movieId 34645
# Saved movieId 34811
# Saved movieId 35050
# Saved movieId 36083
# Saved movieId 36392
# Saved movieId 36509
# Saved movieId 36519
# Saved movieId 36529
# Saved movieId 36553
# Saved movieId 36752
# Saved movieId 36850
# Saved movieId 37335
# Saved movieId 37380
# Saved movieId 37386
# Saved movieId 37477
# Saved movieId 37727
# Saved movieId 37733
# Saved movieId 37824
# Saved movieId 37830
# Saved movieId 37853
# Saved movieId 38046
# Saved movieId 38095
# Saved movieId 38294
# Saved movieId 38583
# Saved movieId 39400
# Saved movieId 39435
# Saved movieId 39777
# Saved movieId 39779
# Saved movieId 39796
# Saved movieId 39896
# Saved movieId 40226
# Saved movieId 40278
# Saved movieId 40339
# Saved movieId 40574
# Saved movieId 40578
# Saved movieId 40851
# Saved movieId 40959
# Saved movieId 40973
# Saved movieId 41136
# Saved movieId 41569
# Saved movieId 41575
# Saved movieId 41627
# Saved movieId 41704
# Saved movieId 41753
# Saved movieId 41914
# Saved movieId 41997
# Saved movieId 42015
# Saved movieId 42385
# Saved movieId 42559
# Saved movieId 42679
# Saved movieId 42718
# Saved movieId 42721
# Saved movieId 42738
# Saved movieId 42946
# Saved movieId 42956
# Saved movieId 43081
# Saved movieId 43267
# Saved movieId 43292
# Saved movieId 43419
# Saved movieId 43549
# Saved movieId 43558
# Saved movieId 43853
# Saved movieId 43917
# Saved movieId 43921
# Saved movieId 43928
# Saved movieId 43932
# Saved movieId 44041
# Saved movieId 44115
# Saved movieId 44191
# Saved movieId 44582
# Saved movieId 44597
# Saved movieId 44825
# Saved movieId 44849
# Saved movieId 44861
# Saved movieId 45183
# Saved movieId 45186
# Saved movieId 45412
# Saved movieId 45442
# Saved movieId 45499
# Saved movieId 45722
# Saved movieId 46034
# Saved movieId 46322
# Saved movieId 46335
# Saved movieId 46430
# Saved movieId 46441
# Saved movieId 46457
# Saved movieId 46500
# Saved movieId 46530
# Saved movieId 46748
# Saved movieId 46855
# Saved movieId 46965
# Saved movieId 46970
# Saved movieId 46972
# Saved movieId 47044
# Saved movieId 47117
# Saved movieId 47200
# Saved movieId 47239
# Saved movieId 47248
# Saved movieId 47254
# Saved movieId 47330
# Saved movieId 47356
# Saved movieId 47394
# Saved movieId 47452
# Saved movieId 47455
# Saved movieId 47458
# Saved movieId 47460
# Saved movieId 47482
# Saved movieId 47538
# Saved movieId 47634
# Saved movieId 47815
# Saved movieId 47902
# Saved movieId 47952
# Saved movieId 47956
# Saved movieId 48093
# Saved movieId 48239
# Saved movieId 48319
# Saved movieId 48412
# Saved movieId 48522
# Saved movieId 48528
# Saved movieId 48536
# Saved movieId 48596
# Saved movieId 48678
# Saved movieId 48711
# Saved movieId 48774
# Saved movieId 48825
# Saved movieId 48833
# Saved movieId 48863
# Saved movieId 48957
# Saved movieId 49272
# Saved movieId 49278
# Saved movieId 49314
# Saved movieId 49530
# Saved movieId 49593
# Saved movieId 49649
# Saved movieId 49651
# Saved movieId 49668
# Saved movieId 49688
# Saved movieId 50003
# Saved movieId 50005
# Saved movieId 50147
# Saved movieId 50151
# Saved movieId 50153
# Saved movieId 50162
# Saved movieId 50271
# Saved movieId 50445
# Saved movieId 50774
# Saved movieId 50794
# Saved movieId 50821
# Saved movieId 50892
# Saved movieId 50944
# Saved movieId 50977
# Saved movieId 51007
# Saved movieId 51077
# Saved movieId 51119
# Saved movieId 51209
# Saved movieId 51255
# Saved movieId 51277
# Saved movieId 51300
# Saved movieId 51412
# Saved movieId 51545
# Saved movieId 51662
# Saved movieId 51891
# Saved movieId 51935
# Saved movieId 51939
# Saved movieId 52182
# Saved movieId 52281
# Saved movieId 52285
# Saved movieId 52287
# Saved movieId 52319
# Saved movieId 52321
# Saved movieId 52418
# Saved movieId 52460
# Saved movieId 52462
# Saved movieId 52551
# Saved movieId 52572
# Saved movieId 52717
# Saved movieId 52722
# Saved movieId 52831
# Saved movieId 52950
# Saved movieId 52956
# Saved movieId 53004
# Saved movieId 53022
# Saved movieId 53125
# Saved movieId 53131
# Saved movieId 53138
# Saved movieId 53140
# Saved movieId 53143
# Saved movieId 53226
# Saved movieId 53342
# Saved movieId 53370
# Saved movieId 53373
# Saved movieId 53375
# Saved movieId 53453
# Saved movieId 53464
# Saved movieId 53519
# Saved movieId 53550
# Saved movieId 53766
# Saved movieId 53788
# Saved movieId 53859
# Saved movieId 53972
# Saved movieId 53996
# Saved movieId 54020
# Saved movieId 54056
# Saved movieId 54067
# Saved movieId 54075
# Saved movieId 54198
# Saved movieId 54239
# Saved movieId 54278
# Saved movieId 54286
# Saved movieId 54445
# Saved movieId 54648
# Saved movieId 54686
# Saved movieId 54736
# Saved movieId 54771
# Saved movieId 54775
# Saved movieId 54872
# Saved movieId 54908
# Saved movieId 54972
# Saved movieId 54986
# Saved movieId 54995
# Saved movieId 54997
# Saved movieId 54999
# Saved movieId 55098
# Saved movieId 55116
# Saved movieId 55167
# Saved movieId 55209
# Saved movieId 55232
# Saved movieId 55247
# Saved movieId 55257
# Saved movieId 55259
# Saved movieId 55402
# Saved movieId 55469
# Saved movieId 55487
# Saved movieId 55603
# Saved movieId 55659
# Saved movieId 55684
# Saved movieId 55721
# Saved movieId 55740
# Saved movieId 55926
# Saved movieId 55995
# Saved movieId 56067
# Saved movieId 56098
# Saved movieId 56156
# Saved movieId 56167
# Saved movieId 56174
# Saved movieId 56511
# Saved movieId 56602
# Saved movieId 56775
# Saved movieId 56801
# Saved movieId 56848
# Saved movieId 57223
# Saved movieId 57326
# Saved movieId 57368
# Saved movieId 57499
# Saved movieId 57528
# Saved movieId 57543
# Saved movieId 57640
# Saved movieId 57692
# Saved movieId 57843
# Saved movieId 57854
# Saved movieId 57873
# Saved movieId 57951
# Saved movieId 58025
# Saved movieId 58033
# Saved movieId 58103
# Saved movieId 58180
# Saved movieId 58295
# Saved movieId 58297
# Saved movieId 58559
# Saved movieId 58627
# Saved movieId 58661
# Saved movieId 58722
# Saved movieId 58743
# Saved movieId 59014
# Saved movieId 59037
# Saved movieId 59040
# Saved movieId 59103
# Saved movieId 59129
# Saved movieId 59173
# Saved movieId 59178
# Saved movieId 59180
# Saved movieId 59182
# Saved movieId 59184
# Saved movieId 59256
# Saved movieId 59315
# Saved movieId 59327
# Saved movieId 59336
# Saved movieId 59369
# Saved movieId 59376
# Saved movieId 59615
# Saved movieId 59784
# Saved movieId 59836
# Saved movieId 59840
# Saved movieId 59844
# Saved movieId 59938
# Saved movieId 59947
# Saved movieId 59954
# Saved movieId 60020
# Saved movieId 60040
# Saved movieId 60072
# Saved movieId 60074
# Saved movieId 60126
# Saved movieId 60193
# Saved movieId 60237
# Saved movieId 60240
# Saved movieId 60471
# Saved movieId 60514
# Saved movieId 60522
# Saved movieId 60684
# Saved movieId 60688
# Saved movieId 60825
# Saved movieId 60937
# Saved movieId 61004
# Saved movieId 61013
# Saved movieId 61024
# Saved movieId 61026
# Saved movieId 61073
# Saved movieId 61132
# Saved movieId 61160
# Saved movieId 61210
# Saved movieId 61248
# Saved movieId 61289
# Saved movieId 61317
# Saved movieId 61350
# Saved movieId 61401
# Saved movieId 61465
# Saved movieId 61493
# Saved movieId 61553
# Saved movieId 61707
# Saved movieId 61818
# Saved movieId 61934
# Saved movieId 62054
# Saved movieId 62081
# Saved movieId 62299
# Saved movieId 62374
# Saved movieId 62383
# Saved movieId 62394
# Saved movieId 62474
# Saved movieId 62801
# Saved movieId 62803
# Saved movieId 62849
# Saved movieId 62999
# Saved movieId 63113
# Saved movieId 63134
# Saved movieId 63181
# Saved movieId 63222
# Saved movieId 63276
# Saved movieId 63391
# Saved movieId 63662
# Saved movieId 63772
# Saved movieId 63788
# Saved movieId 63826
# Saved movieId 63859
# Saved movieId 64030
# Saved movieId 64231
# Saved movieId 64234
# Saved movieId 64368
# Saved movieId 64645
# Saved movieId 64695
# Saved movieId 64921
# Saved movieId 64997
# Saved movieId 65204
# Saved movieId 65300
# Saved movieId 65370
# Saved movieId 65400
# Saved movieId 65514
# Saved movieId 65552
# Saved movieId 65588
# Saved movieId 65596
# Saved movieId 65631
# Saved movieId 65682
# Saved movieId 65802
# Saved movieId 65982
# Saved movieId 66015
# Saved movieId 66130
# Saved movieId 66252
# Saved movieId 66365
# Saved movieId 66539
# Saved movieId 66584
# Saved movieId 66618
# Saved movieId 66639
# Saved movieId 66785
# Saved movieId 66808
# Saved movieId 66868
# Saved movieId 67197
# Saved movieId 67252
# Saved movieId 67361
# Saved movieId 67508
# Saved movieId 67695
# Saved movieId 67809
# Saved movieId 67867
# Saved movieId 67869
# Saved movieId 67876
# Saved movieId 67896
# Saved movieId 67923
# Saved movieId 67929
# Saved movieId 67931
# Saved movieId 67980
# Saved movieId 68033
# Saved movieId 68153
# Saved movieId 68157
# Saved movieId 68161
# Saved movieId 68205
# Saved movieId 68319
# Saved movieId 68358
# Saved movieId 68480
# Saved movieId 68482
# Saved movieId 68486
# Saved movieId 68574
# Saved movieId 68597
# Saved movieId 68791
# Saved movieId 68793
# Saved movieId 68831
# Saved movieId 68855
# Saved movieId 68915
# Saved movieId 68959
# Saved movieId 69042
# Saved movieId 69095
# Saved movieId 69131
# Saved movieId 69136
# Saved movieId 69217
# Saved movieId 69275
# Saved movieId 69278
# Saved movieId 69324
# Saved movieId 69356
# Saved movieId 69370
# Saved movieId 69381
# Saved movieId 69421
# Saved movieId 69481
# Saved movieId 69485
# Saved movieId 69493
# Saved movieId 69509
# Saved movieId 69524
# Saved movieId 69526
# Saved movieId 69644
# Saved movieId 69654
# Saved movieId 69714
# Saved movieId 69746
# Saved movieId 69805
# Saved movieId 69821
# Saved movieId 69947
# Saved movieId 69964
# Saved movieId 70050
# Saved movieId 70181
# Saved movieId 70204
# Saved movieId 70223
# Saved movieId 70336
# Saved movieId 70361
# Saved movieId 70451
# Saved movieId 70465
# Saved movieId 70490
# Saved movieId 70495
# Saved movieId 70531
# Saved movieId 70533
# Saved movieId 70591
# Saved movieId 70607
# Saved movieId 70697
# Saved movieId 70706
# Saved movieId 70728
# Saved movieId 70837
# Saved movieId 70914
# Saved movieId 71007
# Saved movieId 71102
# Saved movieId 71129
# Saved movieId 71133
# Saved movieId 71141
# Saved movieId 71154
# Saved movieId 71156
# Saved movieId 71241
# Saved movieId 71254
# Saved movieId 71460
# Saved movieId 71482
# Saved movieId 71494
# Saved movieId 71530
# Saved movieId 71533
# Saved movieId 71535
# Saved movieId 71573
# Saved movieId 71691
# Saved movieId 71779
# Saved movieId 71808
# Saved movieId 71840
# Saved movieId 71910
# Saved movieId 71999
# Saved movieId 72161
# Saved movieId 72165
# Saved movieId 72167
# Saved movieId 72171
# Saved movieId 72209
# Saved movieId 72258
# Saved movieId 72298
# Saved movieId 72360
# Saved movieId 72369
# Saved movieId 72378
# Saved movieId 72489
# Saved movieId 72514
# Saved movieId 72591
# Saved movieId 72601
# Saved movieId 72672
# Saved movieId 72762
# Saved movieId 72840
# Saved movieId 72842
# Saved movieId 72852
# Saved movieId 72872
# Saved movieId 72874
# Saved movieId 72923
# Saved movieId 72998
# Saved movieId 73017
# Saved movieId 73049
# Saved movieId 73114
# Saved movieId 73185
# Saved movieId 73268
# Saved movieId 73321
# Saved movieId 73323
# Saved movieId 73390
# Saved movieId 73475
# Saved movieId 73488
# Saved movieId 73499
# Saved movieId 73569
# Saved movieId 73678
# Saved movieId 73730
# Saved movieId 73741
# Saved movieId 73776
# Saved movieId 73829
# Saved movieId 73879
# Saved movieId 73914
# Saved movieId 73929
# Saved movieId 73954
# Saved movieId 74099
# Saved movieId 74111
# Saved movieId 74115
# Saved movieId 74139
# Saved movieId 74204
# Saved movieId 74271
# Saved movieId 74302
# Saved movieId 74404
# Saved movieId 74406
# Saved movieId 74438
# Saved movieId 74484
# Saved movieId 74510
# Saved movieId 74532
# Saved movieId 74580
# Saved movieId 74619
# Saved movieId 74641
# Saved movieId 74668
# Saved movieId 74685
# Saved movieId 74795
# Saved movieId 74799
# Saved movieId 74851
# Saved movieId 74857
# Saved movieId 74886
# Saved movieId 75397
# Saved movieId 75805
# Saved movieId 75808
# Saved movieId 75938
# Saved movieId 75985
# Saved movieId 76130
# Saved movieId 76175
# Saved movieId 76238
# Saved movieId 76241
# Saved movieId 76251
# Saved movieId 76293
# Saved movieId 76743
# Saved movieId 76873
# Saved movieId 77201
# Saved movieId 77364
# Saved movieId 77416
# Saved movieId 77540
# Saved movieId 77561
# Saved movieId 77667
# Saved movieId 77729
# Saved movieId 77731
# Saved movieId 77770
# Saved movieId 77818
# Saved movieId 77866
# Saved movieId 77893
# Saved movieId 77896
# Saved movieId 78003
# Saved movieId 78041
# Saved movieId 78054
# Saved movieId 78057
# Saved movieId 78105
# Saved movieId 78128
# Saved movieId 78130
# Saved movieId 78467
# Saved movieId 78469
# Saved movieId 78612
# Saved movieId 78698
# Saved movieId 78729
# Saved movieId 78739
# Saved movieId 78832
# Saved movieId 78893
# Saved movieId 78984
# Saved movieId 79057
# Saved movieId 79109
# Saved movieId 79132
# Saved movieId 79139
# Saved movieId 79185
# Saved movieId 79222
# Saved movieId 79224
# Saved movieId 79234
# Saved movieId 79293
# Saved movieId 79388
# Saved movieId 79496
# Saved movieId 79507
# Saved movieId 79553
# Saved movieId 79580
# Saved movieId 79592
# Saved movieId 79599
# Saved movieId 79607
# Saved movieId 79617
# Saved movieId 79653
# Saved movieId 79695
# Saved movieId 79702
# Saved movieId 79794
# Saved movieId 79796
# Saved movieId 79879
# Saved movieId 79895
# Saved movieId 80026
# Saved movieId 80033
# Saved movieId 80049
# Saved movieId 80083
# Saved movieId 80124
# Saved movieId 80154
# Saved movieId 80162
# Saved movieId 80189
# Saved movieId 80206
# Saved movieId 80219
# Saved movieId 80226
# Saved movieId 80269
# Saved movieId 80363
# Saved movieId 80398
# Saved movieId 80405
# Saved movieId 80617
# Saved movieId 80646
# Saved movieId 80648
# Saved movieId 80731
# Saved movieId 80990
# Saved movieId 81132
# Saved movieId 81156
# Saved movieId 81195
# Saved movieId 81229
# Saved movieId 81314
# Saved movieId 81427
# Saved movieId 81451
# Saved movieId 81497
# Saved movieId 81520
# Saved movieId 81564
# Saved movieId 81660
# Saved movieId 81744
# Saved movieId 81782
# Saved movieId 81834
# Saved movieId 81993
# Saved movieId 82017
# Saved movieId 82242
# Saved movieId 82300
# Saved movieId 82438
# Saved movieId 82447
# Saved movieId 82461
# Saved movieId 82529
# Saved movieId 82631
# Saved movieId 82641
# Saved movieId 82744
# Saved movieId 82765
# Saved movieId 82928
# Saved movieId 83038
# Saved movieId 83256
# Saved movieId 83266
# Saved movieId 83349
# Saved movieId 83374
# Saved movieId 83424
# Saved movieId 83430
# Saved movieId 83450
# Saved movieId 83478
# Saved movieId 83613
# Saved movieId 83760
# Saved movieId 83831
# Saved movieId 84140
# Saved movieId 84173
# Saved movieId 84181
# Saved movieId 84183
# Saved movieId 84187
# Saved movieId 84508
# Saved movieId 84523
# Saved movieId 84565
# Saved movieId 84567
# Saved movieId 84613
# Saved movieId 84619
# Saved movieId 84643
# Saved movieId 84736
# Saved movieId 84796
# Saved movieId 84834
# Saved movieId 84836
# Saved movieId 84942
# Saved movieId 84944
# Saved movieId 85020
# Saved movieId 85056
# Saved movieId 85106
# Saved movieId 85131
# Saved movieId 85207
# Saved movieId 85215
# Saved movieId 85261
# Saved movieId 85293
# Saved movieId 85298
# Saved movieId 85334
# Saved movieId 85342
# Saved movieId 85354
# Saved movieId 85401
# Saved movieId 85414
# Saved movieId 85510
# Saved movieId 85796
# Saved movieId 85889
# Saved movieId 85997
# Saved movieId 86142
# Saved movieId 86173
# Saved movieId 86190
# Saved movieId 86233
# Saved movieId 86244
# Saved movieId 86300
# Saved movieId 86332
# Saved movieId 86471
# Saved movieId 86497
# Saved movieId 86628
# Saved movieId 86644
# Saved movieId 86815
# Saved movieId 86835
# Saved movieId 86841
# Saved movieId 86866
# Saved movieId 86880
# Saved movieId 86892
# Saved movieId 86982
# Saved movieId 87173
# Saved movieId 87192
# Saved movieId 87197
# Saved movieId 87222
# Saved movieId 87225
# Saved movieId 87232
# Saved movieId 87430
# Saved movieId 87433
# Saved movieId 87520
# Saved movieId 87529
# Saved movieId 87547
# Saved movieId 87564
# Saved movieId 87745
# Saved movieId 87763
# Saved movieId 87785
# Saved movieId 88125
# Saved movieId 88140
# Saved movieId 88168
# Saved movieId 88274
# Saved movieId 88327
# Saved movieId 88495
# Saved movieId 88580
# Saved movieId 88744
# Saved movieId 88761
# Saved movieId 88812
# Saved movieId 88879
# Saved movieId 88889
# Saved movieId 88959
# Saved movieId 89002
# Saved movieId 89060
# Saved movieId 89087
# Saved movieId 89190
# Saved movieId 89341
# Saved movieId 89343
# Saved movieId 89371
# Saved movieId 89478
# Saved movieId 89551
# Saved movieId 89623
# Saved movieId 89629
# Saved movieId 89650
# Saved movieId 89701
# Saved movieId 89703
# Saved movieId 89745
# Saved movieId 89794
# Saved movieId 89840
# Saved movieId 89862
# Saved movieId 89872
# Saved movieId 89883
# Saved movieId 89930
# Saved movieId 89983
# Saved movieId 90017
# Saved movieId 90203
# Saved movieId 90243
# Saved movieId 90249
# Saved movieId 90403
# Saved movieId 90434
# Saved movieId 90460
# Saved movieId 90524
# Saved movieId 90545
# Saved movieId 90566
# Saved movieId 90598
# Saved movieId 90600
# Saved movieId 90620
# Saved movieId 90624
# Saved movieId 90662
# Saved movieId 90717
# Saved movieId 90738
# Saved movieId 90746
# Saved movieId 90751
# Saved movieId 90806
# Saved movieId 90873
# Saved movieId 90888
# Saved movieId 90914
# Saved movieId 90935
# Saved movieId 91014
# Saved movieId 91031
# Saved movieId 91054
# Saved movieId 91056
# Saved movieId 91096
# Saved movieId 91112
# Saved movieId 91241
# Saved movieId 91250
# Saved movieId 91273
# Saved movieId 91371
# Saved movieId 91416
# Saved movieId 91421
# Saved movieId 91423
# Saved movieId 91483
# Saved movieId 91485
# Saved movieId 91500
# Saved movieId 91509
# Saved movieId 91529
# Saved movieId 91535
# Saved movieId 91542
# Saved movieId 91591
# Saved movieId 91630
# Saved movieId 91634
# Saved movieId 91660
# Saved movieId 91768
# Saved movieId 91786
# Saved movieId 91834
# Saved movieId 91842
# Saved movieId 91933
# Saved movieId 91957
# Saved movieId 91974
# Saved movieId 91976
# Saved movieId 92008
# Saved movieId 92032
# Saved movieId 92085
# Saved movieId 92096
# Saved movieId 92172
# Saved movieId 92198
# Saved movieId 92222
# Saved movieId 92234
# Saved movieId 92264
# Saved movieId 92268
# Saved movieId 92393
# Saved movieId 92420
# Saved movieId 92507
# Saved movieId 92518
# Saved movieId 92672
# Saved movieId 92681
# Saved movieId 92804
# Saved movieId 92817
# Saved movieId 92819
# Saved movieId 92829
# Saved movieId 92938
# Saved movieId 93142
# Saved movieId 93172
# Saved movieId 93196
# Saved movieId 93297
# Saved movieId 93326
# Saved movieId 93363
# Saved movieId 93496
# Saved movieId 93510
# Saved movieId 93520
# Saved movieId 93522
# Saved movieId 93547
# Saved movieId 93563
# Saved movieId 93610
# Saved movieId 93621
# Saved movieId 93719
# Saved movieId 93748
# Saved movieId 93766
# Saved movieId 93805
# Saved movieId 93834
# Saved movieId 93838
# Saved movieId 93923
# Saved movieId 94011
# Saved movieId 94018
# Saved movieId 94190
# Saved movieId 94405
# Saved movieId 94444
# Saved movieId 94480
# Saved movieId 94777
# Saved movieId 94780
# Saved movieId 94864
# Saved movieId 94985
# Saved movieId 94998
# Saved movieId 95032
# Saved movieId 95165
# Saved movieId 95167
# Saved movieId 95182
# Saved movieId 95207
# Saved movieId 95298
# Saved movieId 95305
# Saved movieId 95484
# Saved movieId 95510
# Saved movieId 95531
# Saved movieId 95572
# Saved movieId 95617
# Saved movieId 95688
# Saved movieId 95697
# Saved movieId 95748
# Saved movieId 95796
# Saved movieId 95875
# Saved movieId 96022
# Saved movieId 96064
# Saved movieId 96079
# Saved movieId 96131
# Saved movieId 96146
# Saved movieId 96148
# Saved movieId 96246
# Saved movieId 96250
# Saved movieId 96277
# Saved movieId 96279
# Saved movieId 96302
# Saved movieId 96367
# Saved movieId 96417
# Saved movieId 96543
# Saved movieId 96590
# Saved movieId 96596
# Saved movieId 96598
# Saved movieId 96601
# Saved movieId 96610
# Saved movieId 96629
# Saved movieId 96631
# Saved movieId 96691
# Saved movieId 96737
# Saved movieId 96775
# Saved movieId 96861
# Saved movieId 96983
# Saved movieId 97042
# Saved movieId 97073
# Saved movieId 97196
# Saved movieId 97280
# Saved movieId 97285
# Saved movieId 97330
# Saved movieId 97384
# Saved movieId 97470
# Saved movieId 97494
# Saved movieId 97709
# Saved movieId 97724
# Saved movieId 97742
# Saved movieId 97757
# Saved movieId 97836
# Saved movieId 97853
# Saved movieId 97855
# Saved movieId 97917
# Saved movieId 97919
# Saved movieId 97940
# Saved movieId 97950
# Saved movieId 97966
# Saved movieId 97968
# Saved movieId 98019
# Saved movieId 98022
# Saved movieId 98030
# Saved movieId 98054
# Saved movieId 98069
# Saved movieId 98072
# Saved movieId 98116
# Saved movieId 98219
# Saved movieId 98239
# Saved movieId 98253
# Saved movieId 98288
# Saved movieId 98358
# Saved movieId 98385
# Saved movieId 98464
# Saved movieId 98467
# Saved movieId 98469
# Saved movieId 98493
# Saved movieId 98497
# Saved movieId 98499
# Saved movieId 98501
# Saved movieId 98503
# Saved movieId 98558
# Saved movieId 98560
# Saved movieId 98589
# Saved movieId 98591
# Saved movieId 98607
# Saved movieId 98623
# Saved movieId 98633
# Saved movieId 98636
# Saved movieId 98755
# Saved movieId 98757
# Saved movieId 98759
# Saved movieId 98783
# Saved movieId 98823
# Saved movieId 98825
# Saved movieId 98829
# Saved movieId 98847
# Saved movieId 98850
# Saved movieId 98852
# Saved movieId 98854
# Saved movieId 98922
# Saved movieId 98949
# Saved movieId 98961
# Saved movieId 98983
# Saved movieId 98989
# Saved movieId 99091
# Saved movieId 99112
# Saved movieId 99114
# Saved movieId 99210
# Saved movieId 99380
# Saved movieId 99470
# Saved movieId 99478
# Saved movieId 99499
# Saved movieId 99525
# Saved movieId 99530
# Saved movieId 99633
# Saved movieId 99728
# Saved movieId 99731
# Saved movieId 99737
# Saved movieId 99739
# Saved movieId 99758
# Saved movieId 99895
# Saved movieId 99899
# Saved movieId 99904
# Saved movieId 99910
# Saved movieId 99970
# Saved movieId 100062
# Saved movieId 100163
# Saved movieId 100205
# Saved movieId 100304
# Saved movieId 100322
# Saved movieId 100419
# Saved movieId 100457
# Saved movieId 100467
# Saved movieId 100469
# Saved movieId 100492
# Saved movieId 100498
# Saved movieId 100505
# Saved movieId 100570
# Saved movieId 100579
# Saved movieId 100737
# Saved movieId 100906
# Saved movieId 101064
# Saved movieId 101076
# Saved movieId 101112
# Saved movieId 101137
# Saved movieId 101178
# Saved movieId 101180
# Saved movieId 101355
# Saved movieId 101362
# Saved movieId 101371
# Saved movieId 101383
# Saved movieId 101489
# Saved movieId 101510
# Saved movieId 101527
# Saved movieId 101577
# Saved movieId 101595
# Saved movieId 101640
# Saved movieId 101653
# Saved movieId 101708
# Saved movieId 101715
# Saved movieId 101719
# Saved movieId 101761
# Saved movieId 101820
# Saved movieId 101864
# Saved movieId 102033
# Saved movieId 102072
# Saved movieId 102088
# Saved movieId 102123
# Saved movieId 102125
# Saved movieId 102135
# Saved movieId 102160
# Saved movieId 102178
# Saved movieId 102188
# Saved movieId 102219
# Saved movieId 102273
# Saved movieId 102425
# Saved movieId 102445
# Saved movieId 102514
# Saved movieId 102517
# ...
# Saved movieId 260621
# Saved movieId 260665
# Saved movieId 260671
# Saved movieId 260677
# Saved movieId 260773
# Saved movieId 260837
# Saved movieId 260857
# Saved movieId 261001
# Saved movieId 261059
# Saved movieId 261129
# Saved movieId 261145
# Saved movieId 261277
# Saved movieId 261291
# Saved movieId 261371
# Saved movieId 261433
# Saved movieId 261515
# Saved movieId 261557
# Saved movieId 261559
# Saved movieId 261585
# Saved movieId 261637
# Saved movieId 261639
# Saved movieId 261643
# Saved movieId 261665
# Saved movieId 261753
# Saved movieId 261755
# Saved movieId 261759
# Saved movieId 261783
# Saved movieId 261815
# Saved movieId 261841
# Saved movieId 261855
# Saved movieId 261883
# Saved movieId 261897
# Saved movieId 261909
# Saved movieId 261939
# Saved movieId 261953
# Saved movieId 261963
# Saved movieId 261965
# Saved movieId 262013
# Saved movieId 262037
# Saved movieId 262061
# Saved movieId 262113
# Saved movieId 262131
# Saved movieId 262257
# Saved movieId 262425
# Saved movieId 262435
# Saved movieId 262451
# Saved movieId 262721
# Saved movieId 262743
# Saved movieId 262755
# Saved movieId 262847
# Saved movieId 262851
# Saved movieId 262863
# Saved movieId 263007
# Saved movieId 263009
# Saved movieId 263033
# Saved movieId 263069
# Saved movieId 263311
# Saved movieId 263331
# Saved movieId 263457
# Saved movieId 263479
# Saved movieId 263491
# Saved movieId 263551
# Saved movieId 263555
# Saved movieId 263619
# Saved movieId 263643
# Saved movieId 263871
# Saved movieId 263875
# Saved movieId 264149
# Saved movieId 264231
# Saved movieId 264233
# Saved movieId 264235
# Saved movieId 264237
# Saved movieId 264239
# Saved movieId 264241
# Saved movieId 264243
# Saved movieId 264245
# Saved movieId 264247
# Saved movieId 264253
# Saved movieId 264255
# Saved movieId 264418
# Saved movieId 264704
# Saved movieId 264888
# Saved movieId 264892
# Saved movieId 264938
# Saved movieId 265114
# Saved movieId 265148
# Saved movieId 265172
# Saved movieId 265204
# Saved movieId 265362
# Saved movieId 265378
# Saved movieId 265412
# Saved movieId 265494
# Saved movieId 265614
# Saved movieId 265616
# Saved movieId 265670
# Saved movieId 265724
# Saved movieId 265758
# Saved movieId 265832
# Saved movieId 265972
# Saved movieId 266030
# Saved movieId 266042
# Saved movieId 266064
# Saved movieId 266100
# Saved movieId 266228
# Saved movieId 266248
# Saved movieId 266264
# Saved movieId 266312
# Saved movieId 266318
# Saved movieId 266320
# Saved movieId 266340
# Saved movieId 266392
# Saved movieId 266400
# Saved movieId 266418
# Saved movieId 266420
# Saved movieId 266428
# Saved movieId 266430
# Saved movieId 266432
# Saved movieId 266442
# Saved movieId 266472
# Saved movieId 266544
# Saved movieId 266574
# Saved movieId 266630
# Saved movieId 266744
# Saved movieId 266818
# Saved movieId 266870
# Saved movieId 266950
# Saved movieId 267280
# Saved movieId 267292
# Saved movieId 267324
# Saved movieId 267470
# Saved movieId 267472
# Saved movieId 267478
# Saved movieId 267480
# Saved movieId 267500
# Saved movieId 267504
# Saved movieId 267550
# Saved movieId 267614
# Saved movieId 267616
# Saved movieId 267632
# Saved movieId 267648
# Saved movieId 267726
# Saved movieId 267926
# Saved movieId 268048
# Saved movieId 268064
# Saved movieId 268198
# Saved movieId 268226
# Saved movieId 268276
# Saved movieId 268286
# Saved movieId 268346
# Saved movieId 268370
# Saved movieId 268404
# Saved movieId 268518
# Saved movieId 268562
# Saved movieId 268630
# Saved movieId 268642
# Saved movieId 268686
# Saved movieId 268776
# Saved movieId 268946
# Saved movieId 269022
# Saved movieId 269036
# Saved movieId 269070
# Saved movieId 269226
# Saved movieId 269278
# Saved movieId 269324
# Saved movieId 269428
# Saved movieId 269492
# Saved movieId 269558
# Saved movieId 269756
# Saved movieId 269764
# Saved movieId 269766
# Saved movieId 269810
# Saved movieId 269824
# Saved movieId 269872
# Saved movieId 269878
# Saved movieId 269884
# Saved movieId 269890
# Saved movieId 269922
# Saved movieId 269942
# Saved movieId 269988
# Saved movieId 270142
# Saved movieId 270216
# Saved movieId 270236
# Saved movieId 270306
# Saved movieId 270368
# Saved movieId 270464
# Saved movieId 270468
# Saved movieId 270470
# Saved movieId 270526
# Saved movieId 270554
# Saved movieId 270660
# Saved movieId 270698
# Saved movieId 270724
# Saved movieId 270774
# Saved movieId 270802
# Saved movieId 270856
# Saved movieId 270868
# Saved movieId 271116
# Saved movieId 271118
# Saved movieId 271192
# Saved movieId 271198
# Saved movieId 271278
# Saved movieId 271288
# Saved movieId 271423
# Saved movieId 271439
# Saved movieId 271507
# Saved movieId 271547
# Saved movieId 271605
# Saved movieId 271677
# Saved movieId 271745
# Saved movieId 271799
# Saved movieId 271889
# Saved movieId 271891
# Saved movieId 272051
# Saved movieId 272079
# Saved movieId 272211
# Saved movieId 272227
# Saved movieId 272407
# Saved movieId 272417
# Saved movieId 272439
# Saved movieId 272457
# Saved movieId 272461
# Saved movieId 272463
# Saved movieId 272467
# Saved movieId 272479
# Saved movieId 272525
# Saved movieId 272575
# Saved movieId 272581
# Saved movieId 272641
# Saved movieId 272679
# Saved movieId 272705
# Saved movieId 272737
# Saved movieId 272803
# Saved movieId 272823
# Saved movieId 272947
# Saved movieId 272949
# Saved movieId 272957
# Saved movieId 273083
# Saved movieId 273129
# Saved movieId 273189
# Saved movieId 273205
# Saved movieId 273249
# Saved movieId 273277
# Saved movieId 273319
# Saved movieId 273399
# Saved movieId 273417
# Saved movieId 273423
# Saved movieId 273519
# Saved movieId 273525
# Saved movieId 273653
# Saved movieId 273707
# Saved movieId 273711
# Saved movieId 273767
# Saved movieId 273819
# Saved movieId 273823
# Saved movieId 273837
# Saved movieId 273851
# Saved movieId 273853
# Saved movieId 273891
# Saved movieId 273931
# Saved movieId 273963
# Saved movieId 273965
# Saved movieId 274005
# Saved movieId 274031
# Saved movieId 274041
# Saved movieId 274045
# Saved movieId 274053
# Saved movieId 274055
# Saved movieId 274065
# Saved movieId 274155
# Saved movieId 274189
# Saved movieId 274195
# Saved movieId 274197
# Saved movieId 274199
# Saved movieId 274201
# Saved movieId 274209
# Saved movieId 274245
# Saved movieId 274255
# Saved movieId 274263
# Saved movieId 274265
# Saved movieId 274267
# Saved movieId 274275
# Saved movieId 274411
# Saved movieId 274495
# Saved movieId 274583
# Saved movieId 274617
# Saved movieId 274631
# Saved movieId 274633
# Saved movieId 274685
# Saved movieId 274781
# Saved movieId 274801
# Saved movieId 274841
# Saved movieId 274897
# Saved movieId 274969
# Saved movieId 274971
# Saved movieId 274983
# Saved movieId 275021
# Saved movieId 275091
# Saved movieId 275095
# Saved movieId 275139
# Saved movieId 275179
# Saved movieId 275201
# Saved movieId 275241
# Saved movieId 275247
# Saved movieId 275265
# Saved movieId 275337
# Saved movieId 275339
# Saved movieId 275343
# Saved movieId 275369
# Saved movieId 275371
# Saved movieId 275373
# Saved movieId 275465
# Saved movieId 275467
# Saved movieId 275505
# Saved movieId 275521
# Saved movieId 275559
# Saved movieId 275561
# Saved movieId 275625
# Saved movieId 275641
# Saved movieId 275665
# Saved movieId 275667
# Saved movieId 275675
# Saved movieId 275677
# Saved movieId 275679
# Saved movieId 275683
# Saved movieId 275687
# Saved movieId 275691
# Saved movieId 275693
# Saved movieId 275779
# Saved movieId 275787
# Saved movieId 275843
# Saved movieId 275927
# Saved movieId 275971
# Saved movieId 276003
# Saved movieId 276051
# Saved movieId 276081
# Saved movieId 276099
# Saved movieId 276129
# Saved movieId 276155
# Saved movieId 276217
# Saved movieId 276231
# Saved movieId 276251
# Saved movieId 276299
# Saved movieId 276317
# Saved movieId 276321
# Saved movieId 276333
# Saved movieId 276343
# Saved movieId 276345
# Saved movieId 276357
# Saved movieId 276363
# Saved movieId 276385
# Saved movieId 276389
# Saved movieId 276391
# Saved movieId 276395
# Saved movieId 276411
# Saved movieId 276429
# Saved movieId 276453
# Saved movieId 276487
# Saved movieId 276513
# Saved movieId 276517
# Saved movieId 276557
# Saved movieId 276565
# Saved movieId 276655
# Saved movieId 276683
# Saved movieId 276711
# Saved movieId 276797
# Saved movieId 276823
# Saved movieId 276845
# Saved movieId 276885
# Saved movieId 276911
# Saved movieId 276929
# Saved movieId 276935
# Saved movieId 276939
# Saved movieId 276941
# Saved movieId 276961
# Saved movieId 277062
# Saved movieId 277074
# Saved movieId 277108
# Saved movieId 277136
# Saved movieId 277160
# Saved movieId 277190
# Saved movieId 277196
# Saved movieId 277258
# Saved movieId 277260
# Saved movieId 277284
# Saved movieId 277324
# Saved movieId 277338
# Saved movieId 277406
# Saved movieId 277410
# Saved movieId 277450
# Saved movieId 277460
# Saved movieId 277470
# Saved movieId 277484
# Saved movieId 277488
# Saved movieId 277496
# Saved movieId 277540
# Saved movieId 277552
# Saved movieId 277624
# Saved movieId 277716
# Saved movieId 277722
# Saved movieId 277742
# Saved movieId 277758
# Saved movieId 277778
# Saved movieId 277842
# Saved movieId 277848
# Saved movieId 277864
# Saved movieId 277894
# Saved movieId 277898
# Saved movieId 277910
# Saved movieId 277954
# Saved movieId 277958
# Saved movieId 277990
# Saved movieId 278008
# Saved movieId 278064
# Saved movieId 278080
# Saved movieId 278082
# Saved movieId 278088
# Saved movieId 278104
# Saved movieId 278124
# Saved movieId 278158
# Saved movieId 278232
# Saved movieId 278296
# Saved movieId 278302
# Saved movieId 278312
# Saved movieId 278344
# Saved movieId 278412
# Saved movieId 278428
# Saved movieId 278460
# Saved movieId 278490
# Saved movieId 278514
# Saved movieId 278578
# Saved movieId 278652
# Saved movieId 278750
# Saved movieId 278752
# Saved movieId 278754
# Saved movieId 278758
# Saved movieId 278762
# Saved movieId 278764
# Saved movieId 278770
# Saved movieId 278774
# Saved movieId 278820
# Saved movieId 278854
# Saved movieId 278966
# Saved movieId 279010
# Saved movieId 279012
# Saved movieId 279014
# Saved movieId 279044
# Saved movieId 279176
# Saved movieId 279212
# Saved movieId 279218
# Saved movieId 279222
# Saved movieId 279224
# Saved movieId 279226
# Saved movieId 279240
# Saved movieId 279278
# Saved movieId 279312
# Saved movieId 279386
# Saved movieId 279392
# Saved movieId 279414
# Saved movieId 279452
# Saved movieId 279460
# Saved movieId 279478
# Saved movieId 279480
# Saved movieId 279490
# Saved movieId 279528
# Saved movieId 279548
# Saved movieId 279564
# Saved movieId 279588
# Saved movieId 279608
# Saved movieId 279620
# Saved movieId 279630
# Saved movieId 279658
# Saved movieId 279660
# Saved movieId 279664
# Saved movieId 279666
# Saved movieId 279670
# Saved movieId 279692
# Saved movieId 279698
# Saved movieId 279700
# Saved movieId 279708
# Saved movieId 279714
# Saved movieId 279718
# Saved movieId 279728
# Saved movieId 279770
# Saved movieId 279778
# Saved movieId 279790
# Saved movieId 279806
# Saved movieId 279856
# Saved movieId 279888
# Saved movieId 279900
# Saved movieId 279926
# Saved movieId 279936
# Saved movieId 279938
# Saved movieId 279956
# Saved movieId 279958
# Saved movieId 280026
# Saved movieId 280050
# Saved movieId 280084
# Saved movieId 280096
# Saved movieId 280112
# Saved movieId 280198
# Saved movieId 280210
# Saved movieId 280218
# Saved movieId 280322
# Saved movieId 280330
# Saved movieId 280352
# Saved movieId 280360
# Saved movieId 280374
# Saved movieId 280390
# Saved movieId 280400
# Saved movieId 280442
# Saved movieId 280490
# Saved movieId 280502
# Saved movieId 280538
# Saved movieId 280594
# Saved movieId 280672
# Saved movieId 280676
# Saved movieId 280690
# Saved movieId 280846
# Saved movieId 280848
# Saved movieId 280930
# Saved movieId 280952
# Saved movieId 280964
# Saved movieId 280968
# Saved movieId 280982
# Saved movieId 280992
# Saved movieId 281008
# Saved movieId 281046
# Saved movieId 281066
# Saved movieId 281074
# Saved movieId 281126
# Saved movieId 281138
# Saved movieId 281146
# Saved movieId 281186
# Saved movieId 281208
# Saved movieId 281260
# Saved movieId 281264
# Saved movieId 281302
# Saved movieId 281306
# Saved movieId 281344
# Saved movieId 281364
# Saved movieId 281370
# Saved movieId 281374
# Saved movieId 281406
# Saved movieId 281416
# Saved movieId 281438
# Saved movieId 281560
# Saved movieId 281564
# Saved movieId 281566
# Saved movieId 281614
# Saved movieId 281662
# Saved movieId 281666
# Saved movieId 281746
# Saved movieId 281818
# Saved movieId 281828
# Saved movieId 281834
# Saved movieId 281868
# Saved movieId 281874
# Saved movieId 281880
# Saved movieId 281922
# Saved movieId 281924
# Saved movieId 281948
# Saved movieId 281960
# Saved movieId 282015
# Saved movieId 282017
# Saved movieId 282025
# Saved movieId 282093
# Saved movieId 282163
# Saved movieId 282217
# Saved movieId 282253
# Saved movieId 282259
# Saved movieId 282445
# Saved movieId 282447
# Saved movieId 282449
# Saved movieId 282493
# Saved movieId 282499
# Saved movieId 282543
# Saved movieId 282561
# Saved movieId 282589
# Saved movieId 282593
# Saved movieId 282641
# Saved movieId 282643
# Saved movieId 282661
# Saved movieId 282671
# Saved movieId 282675
# Saved movieId 282683
# Saved movieId 282721
# Saved movieId 282795
# Saved movieId 282821
# Saved movieId 282875
# Saved movieId 282905
# Saved movieId 282923
# Saved movieId 282977
# Saved movieId 282985
# Saved movieId 282997
# Saved movieId 282999
# Saved movieId 283031
# Saved movieId 283067
# Saved movieId 283125
# Saved movieId 283139
# Saved movieId 283145
# Saved movieId 283163
# Saved movieId 283223
# Saved movieId 283225
# Saved movieId 283259
# Saved movieId 283289
# Saved movieId 283293
# Saved movieId 283317
# Saved movieId 283345
# Saved movieId 283351
# Saved movieId 283373
# Saved movieId 283413
# Saved movieId 283435
# Saved movieId 283457
# Saved movieId 283477
# Saved movieId 283547
# Saved movieId 283549
# Saved movieId 283551
# Saved movieId 283553
# Saved movieId 283555
# Saved movieId 283557
# Saved movieId 283605
# Saved movieId 283729
# Saved movieId 283743
# Saved movieId 283873
# Saved movieId 283889
# Saved movieId 283891
# Saved movieId 283919
# Saved movieId 284055
# Saved movieId 284075
# Saved movieId 284093
# Saved movieId 284163
# Saved movieId 284287
# Saved movieId 284293
# Saved movieId 284437
# Saved movieId 284489
# Saved movieId 284755
# Saved movieId 284793
# Saved movieId 285017
# Saved movieId 285045
# Saved movieId 285109
# Saved movieId 285117
# Saved movieId 285121
# Saved movieId 285143
# Saved movieId 285151
# Saved movieId 285153
# Saved movieId 285155
# Saved movieId 285195
# Saved movieId 285199
# Saved movieId 285227
# Saved movieId 285257
# Saved movieId 285301
# Saved movieId 285361
# Saved movieId 285593
# Saved movieId 285649
# Saved movieId 285757
# Saved movieId 285775
# Saved movieId 285783
# Saved movieId 285859
# Saved movieId 285909
# Saved movieId 285913
# Saved movieId 285925
# Saved movieId 285947
# Saved movieId 285975
# Saved movieId 285977
# Saved movieId 286015
# Saved movieId 286031
# Saved movieId 286107
# Saved movieId 286111
# Saved movieId 286133
# Saved movieId 286135
# Saved movieId 286163
# Saved movieId 286167
# Saved movieId 286177
# Saved movieId 286201
# Saved movieId 286233
# Saved movieId 286303
# Saved movieId 286411
# Saved movieId 286435
# Saved movieId 286523
# Saved movieId 286551
# Saved movieId 286595
# Saved movieId 286677
# Saved movieId 286703
# Saved movieId 286735
# Saved movieId 286841
# Saved movieId 286871
# Saved movieId 286877
# Saved movieId 286889
# Saved movieId 286897
# Saved movieId 286899
# Saved movieId 286901
# Saved movieId 286905
# Saved movieId 286915
# Saved movieId 286943
# Saved movieId 286953
# Saved movieId 286955
# Saved movieId 287091
# Saved movieId 287097
# Saved movieId 287129
# Saved movieId 287131
# Saved movieId 287179
# Saved movieId 287181
# Saved movieId 287213
# Saved movieId 287215
# Saved movieId 287349
# Saved movieId 287377
# Saved movieId 287397
# Saved movieId 287527
# Saved movieId 287539
# Saved movieId 287563
# Saved movieId 287613
# Saved movieId 287617
# Saved movieId 287621
# Saved movieId 287627
# Saved movieId 287639
# Saved movieId 287657
# Saved movieId 287677
# Saved movieId 287679
# Saved movieId 287685
# Saved movieId 287687
# Saved movieId 287701
# Saved movieId 287707
# Saved movieId 287737
# Saved movieId 287807
# Saved movieId 287827
# Saved movieId 287833
# Saved movieId 287835
# Saved movieId 287859
# Saved movieId 288001
# Saved movieId 288025
# Saved movieId 288049
# Saved movieId 288109
# Saved movieId 288167
# Saved movieId 288209
# Saved movieId 288265
# Saved movieId 288283
# Saved movieId 288303
# Saved movieId 288311
# Saved movieId 288353
# Saved movieId 288441
# Saved movieId 288507
# Saved movieId 288509
# Saved movieId 288517
# Saved movieId 288519
# Saved movieId 288521
# Saved movieId 288555
# Saved movieId 288557
# Saved movieId 288565
# Saved movieId 288577
# Saved movieId 288599
# Saved movieId 288631
# Saved movieId 288671
# Saved movieId 288679
# Saved movieId 288727
# Saved movieId 288853
# Saved movieId 288873
# Saved movieId 288895
# Saved movieId 288897
# Saved movieId 288931
# Saved movieId 288967
# Saved movieId 288971

# %%
print(movies_df.columns)
# Out:
# Index(['movieId', 'imdbId', 'tmdbId'], dtype='object')

# %%
# procentsats af reviews med indhold
total_reviews = 0
non_empty_reviews = 0
with open("data/reviews_final_one_AA.csv", 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    next(reader)  # skip header
    for row in reader:
        total_reviews += 1
        reviews = row[1]
        if reviews.strip():
            non_empty_reviews += 1

print(f"Percentage of reviews with content: {non_empty_reviews / total_reviews * 100:.2f}%")
# Out:
# Percentage of reviews with content: 27.92%

# %%
# hvor mange reviews per movie i gennemsnit for film med reviews
total_reviews_count = 0
movies_with_reviews = 0
with open("data/reviews_final_one_AA.csv", 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    next(reader)  # skip header
    for row in reader:
        reviews = row[1]
        if reviews.strip():
            review_list = reviews.split("|")
            total_reviews_count += len(review_list)
            movies_with_reviews += 1

average_reviews_per_movie = total_reviews_count / movies_with_reviews
print(f"Average number of reviews per movie (for movies with reviews): {average_reviews_per_movie:.2f}")
# Out:
# Average number of reviews per movie (for movies with reviews): 2.14
